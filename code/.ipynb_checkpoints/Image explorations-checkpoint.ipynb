# %%
import PIL # pillow needed for scipy.misc's image functions
from scipy import misc
from matplotlib import pyplot as plt # for plotting

# %%
face = misc.face()
misc.imsave('face.png', face) # First we need to create the PNG file

face = misc.imread('face.png')
type(face)      

face.shape, face.dtype
# Out:
# ((768, 1024, 3), dtype('uint8'))

# %%
plt.imshow(face, cmap=plt.cm.gray)  
plt.show()

# %%
aaa = misc.imread('../../Images_experiment/0001TP_008730.png')
plt.imshow(aaa, cmap=plt.cm.gray)  
plt.show()

# %%
aaa.shape
# Out:
# (360, 480)

# %%
bbb = misc.imread('../../Images_experiment/0001TP_008550.png')
plt.imshow(bbb)  
plt.show()

# %%
bbb.shape
# Out:
# (360, 480, 3)

# %%
aaa.shape
# Out:
# (360, 480)

# %%
import numpy as np
height, width = 360, 480
nchannels = 3
new_img = np.resize(aaa, (height, width, nchannels))

# %%
new_img.shape
# Out:
# (360, 480, 3)

# %%
plt.imshow(new_img[:, :, 0])  
plt.show()

# %%
new_img.max()
# Out:
# 11

# %%
from PIL import ImageOps
PIL.ImageOps.colorize(aaa, (0, 0, 0), (255, 255, 255))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-1e79811471ba> in <module>()
#       1 from PIL import ImageOps
# ----> 2 PIL.ImageOps.colorize(aaa, (0, 0, 0), (255, 255, 255))
#
# /home/lilyhu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/PIL/ImageOps.py in colorize(image, black, white)
#     148     :return: An image.
#     149     """
# --> 150     assert image.mode == "L"
#     151     black = _color(black, "RGB")
#     152     white = _color(white, "RGB")
#
# AttributeError: 'numpy.ndarray' object has no attribute 'mode'

# %%
 PIL.ImageOps.grayscale(bbb)

# %%
from PIL import Image
im = Image.open('../../Images_experiment/0001TP_008550.png')

# %%
plt.imshow(np.array(im))
plt.show()

# %%
converted_grey = im.convert('L')
plt.imshow(np.array(converted_grey))
plt.show()

# %%
convert_grey_2_rgb = ImageOps.colorize(converted_grey, (0, 0, 0), (255, 255, 255))
plt.imshow(np.array(convert_grey_2_rgb))
plt.show()

# %%
np.array(convert_grey_2_rgb).shape
# Out:
# (360, 480, 3)

# %%
np.array(im).shape
# Out:
# (360, 480, 3)

# %%
type(np.array(im)[0:3,0:3,0])
# Out:
# numpy.ndarray

# %%
np.array(im)[0:3,0:3,0]
# Out:
# array([[37, 33, 33],
#        [37, 37, 33],
#        [36, 36, 35]], dtype=uint8)

# %%
Image.fromarray(np.array(im)[0:3,0:3,0])
# Out:
# <PIL.Image.Image image mode=L size=3x3 at 0x7F680D2FFB38>

# %%
np.array(im.convert('L')).max()
# Out:
# 235

# %%
grayscale2threechannel_as_array(np.array(im.convert('L'))).shape
# Out:
# (360, 480, 3)

# %%
np.array(im.convert('L').convert('RGB'))
# Out:
# array([[[35, 35, 35],
#         [31, 31, 31],
#         [32, 32, 32],
#         ...,
#         [48, 48, 48],
#         [40, 40, 40],
#         [37, 37, 37]],
#
#        [[36, 36, 36],
#         [36, 36, 36],
#         [32, 32, 32],
#         ...,
#         [36, 36, 36],
#         [41, 41, 41],
#         [46, 46, 46]],
#
#        [[35, 35, 35],
#         [34, 34, 34],
#         [34, 34, 34],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [46, 46, 46]],
#
#        ...,
#        [[28, 28, 28],
#         [23, 23, 23],
#         [21, 21, 21],
#         ...,
#         [26, 26, 26],
#         [22, 22, 22],
#         [20, 20, 20]],
#
#        [[25, 25, 25],
#         [21, 21, 21],
#         [19, 19, 19],
#         ...,
#         [25, 25, 25],
#         [24, 24, 24],
#         [23, 23, 23]],
#
#        [[23, 23, 23],
#         [20, 20, 20],
#         [22, 22, 22],
#         ...,
#         [23, 23, 23],
#         [22, 22, 22],
#         [24, 24, 24]]], dtype=uint8)

# %%
Image.fromarray(np.array([[23, 23, 23],[20, 20, 20], [22, 22, 22]]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/lilyhu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2194             typekey = (1, 1) + shape[2:], arr['typestr']
# -> 2195             mode, rawmode = _fromarray_typemap[typekey]
#    2196         except KeyError:
#
# KeyError: ((1, 1), '<i8')
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-115-c2aed13eef28> in <module>()
# ----> 1 Image.fromarray(np.array([[23, 23, 23],[20, 20, 20], [22, 22, 22]]))
#
# /home/lilyhu/anaconda3/envs/tensorflow/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2196         except KeyError:
#    2197             # print(typekey)
# -> 2198             raise TypeError("Cannot handle this data type")
# ...

# %%
test = np.array([[23, 23, 23],[20, 20, 20], [22, 22, 22]], dtype='uint8')
